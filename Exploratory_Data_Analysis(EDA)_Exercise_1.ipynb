# %% [markdown]
# Pandas Practice
# ====
#
# ![](images/iris.png)
#
# Fisher's Iris Data

# %%
reset -fs

# %%
import pandas as pd

# %%
iris = pd.read_csv('data/iris.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# How many irises are the data set?

# %%
iris.info()
iris.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB
# (150, 5)

# %% [markdown]
# Calculate the mean, median, mode for petal length

# %%
print(iris['petal_length'].mean())
print(iris['petal_length'].median())
print(iris['petal_length'].mode())
iris.describe()
# Out:
# 3.7586666666666693
# 4.35
# 0    1.5
# dtype: float64
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# What can you conclude about the distribution for petal length?

# %% [markdown]
# More than half of all shells have an above average shell length of 3.76 and more the most common shell length for a 0.1 binning is a length of 1.5.

# %% [markdown]
# What is the smallest and largest value for petal lenth?

# %%
print(iris['petal_length'].max())
print(iris['petal_length'].min())
# Out:
# 6.9
# 1.0

# %% [markdown]
# Calculate the variance and standard deviation for petal length

# %%
print(iris['petal_length'].std())
print(iris['petal_length'].var())
# Out:
# 1.7644204199522617
# 3.1131794183445156

# %% [markdown]
# Calculate the basic descriptive statistics for all columns of the iris data set with a single command.

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# What is the overall average for _sepal length_?

# %%
5.84

# %% [markdown]
# Use DataFrame grouping function to determine the count by species.

# %%
iris.groupby('species').count()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa                50           50            50           50
# Iris-versicolor            50           50            50           50
# Iris-virginica             50           50            50           50

# %% [markdown]
# Use DataFrame grouping function to determine the average length and width of sepals and pedals by species.

# %%
iris.groupby('species').mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %% [markdown]
# Add the sum of the sepal width and length as a new column to your data frame.

# %%
iris['sepalsum'] = iris.sepal_length + iris.sepal_width

# %% [markdown]
# Visualize petal length with a histogram

# %%
import matplotlib.pyplot as plt
plt.xlabel('petal length')
plt.ylabel('Count of occurence')
iris.petal_length.hist();
#iris.petal_length.plot(kind = 'hist');

# %% [markdown]
# Describe the distribution

# %% [markdown]
# There appear to be two types of flowers with regard two the petal length one grouped around [1,2] and one grouped around [3,7]

# %% [markdown]
# Which is more informative the summary statistics or visualizations?

# %% [markdown]
# Visualization displays significantly more information

# %% [markdown]
# Visualize petal length and width with a "scatter_matrix"

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(iris[["petal_length", "petal_width"]],
              diagonal='hist');

# %% [markdown]
# Describe the joint distribution

# %% [markdown]
# Two clustered regions of length and width for small lengths and widths and large lengths and widths

# %% [markdown]
# Create a new column with a rough estimate of petal area by multiplying petal length and width together.

# %%
iris['petal_area'] = iris.petal_length * iris.petal_width

# %% [markdown]
# ----
# Challenge Exercises
# ----

# %% [markdown]
# Create a new dataframe with petal areas greater than $1cm^2$.

# %%
iris_area_small = iris[iris.petal_area < 1]
iris_area_small
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species  \
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# 12           4.8          3.0           1.4          0.1  Iris-setosa
# 13           4.3          3.0           1.1          0.1  Iris-setosa
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 15           5.7          4.4           1.5          0.4  Iris-setosa
# 16           5.4          3.9           1.3          0.4  Iris-setosa
# 17           5.1          3.5           1.4          0.3  Iris-setosa
# 18           5.7          3.8           1.7          0.3  Iris-setosa
# 19           5.1          3.8           1.5          0.3  Iris-setosa
# 20           5.4          3.4           1.7          0.2  Iris-setosa
# 21           5.1          3.7           1.5          0.4  Iris-setosa
# 22           4.6          3.6           1.0          0.2  Iris-setosa
# 23           5.1          3.3           1.7          0.5  Iris-setosa
# 24           4.8          3.4           1.9          0.2  Iris-setosa
# 25           5.0          3.0           1.6          0.2  Iris-setosa
# 26           5.0          3.4           1.6          0.4  Iris-setosa
# 27           5.2          3.5           1.5          0.2  Iris-setosa
# 28           5.2          3.4           1.4          0.2  Iris-setosa
# 29           4.7          3.2           1.6          0.2  Iris-setosa
# 30           4.8          3.1           1.6          0.2  Iris-setosa
# 31           5.4          3.4           1.5          0.4  Iris-setosa
# 32           5.2          4.1           1.5          0.1  Iris-setosa
# 33           5.5          4.2           1.4          0.2  Iris-setosa
# 34           4.9          3.1           1.5          0.1  Iris-setosa
# 35           5.0          3.2           1.2          0.2  Iris-setosa
# 36           5.5          3.5           1.3          0.2  Iris-setosa
# 37           4.9          3.1           1.5          0.1  Iris-setosa
# 38           4.4          3.0           1.3          0.2  Iris-setosa
# 39           5.1          3.4           1.5          0.2  Iris-setosa
# 40           5.0          3.5           1.3          0.3  Iris-setosa
# 41           4.5          2.3           1.3          0.3  Iris-setosa
# 42           4.4          3.2           1.3          0.2  Iris-setosa
# 43           5.0          3.5           1.6          0.6  Iris-setosa
# 44           5.1          3.8           1.9          0.4  Iris-setosa
# 45           4.8          3.0           1.4          0.3  Iris-setosa
# 46           5.1          3.8           1.6          0.2  Iris-setosa
# 47           4.6          3.2           1.4          0.2  Iris-setosa
# 48           5.3          3.7           1.5          0.2  Iris-setosa
# 49           5.0          3.3           1.4          0.2  Iris-setosa
#
#     sepalsum  petal_area
# 0        8.6        0.28
# 1        7.9        0.28
# 2        7.9        0.26
# 3        7.7        0.30
# 4        8.6        0.28
# 5        9.3        0.68
# 6        8.0        0.42
# 7        8.4        0.30
# 8        7.3        0.28
# 9        8.0        0.15
# 10       9.1        0.30
# 11       8.2        0.32
# 12       7.8        0.14
# 13       7.3        0.11
# 14       9.8        0.24
# 15      10.1        0.60
# 16       9.3        0.52
# 17       8.6        0.42
# 18       9.5        0.51
# 19       8.9        0.45
# 20       8.8        0.34
# 21       8.8        0.60
# 22       8.2        0.20
# 23       8.4        0.85
# 24       8.2        0.38
# 25       8.0        0.32
# 26       8.4        0.64
# 27       8.7        0.30
# 28       8.6        0.28
# 29       7.9        0.32
# 30       7.9        0.32
# 31       8.8        0.60
# 32       9.3        0.15
# 33       9.7        0.28
# 34       8.0        0.15
# 35       8.2        0.24
# 36       9.0        0.26
# 37       8.0        0.15
# 38       7.4        0.26
# 39       8.5        0.30
# 40       8.5        0.39
# 41       6.8        0.39
# 42       7.6        0.26
# 43       8.5        0.96
# 44       8.9        0.76
# 45       7.8        0.42
# 46       8.9        0.32
# 47       7.8        0.28
# 48       9.0        0.30
# 49       8.3        0.28

# %% [markdown]
# Create 3 new dataframes, one for each species. Use the entire dataset.

# %% [markdown]
# Iris-setosa
# Iris-versicolor
# Iris-virginica

# %%
iris_setosa = iris[iris.species == 'Iris-setosa']
iris_versicolor = iris[iris.species == 'Iris-versicolor']
iris_virginica = iris[iris.species == 'Iris-virginica']

# %% [markdown]
# <br>
# <br>
# <br>
#
# ----
